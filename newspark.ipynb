# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *
# DBTITLE 1,Create a new column 'Year' in df_calendar
df_calendar = df_calendar.withColumn('Year', year(df_calendar.Date))
